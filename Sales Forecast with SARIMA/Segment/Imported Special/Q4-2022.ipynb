# %%
import pandas as pd
import numpy as np
import warnings
import itertools
import matplotlib
import matplotlib.pyplot as plt
import datetime
from pylab import rcParams
import statsmodels.api as sm
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.tsa.stattools import adfuller

# Ignore the warning, can comment this 
warnings.filterwarnings("ignore")

# For graphing purpose, can change 
plt.style.use('seaborn-bright')
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# # Uploading the data and Indexing with TIME

# %%
# Import the data
df = pd.read_csv("SPECIAL.csv")
df['date'] = pd.to_datetime(df['date'])

# Set the date as index 
df = df.set_index('date')

# Select the proper time period for weekly aggreagation
df = df['2019-12-30':'2022-04-10'].resample('W').sum()

df.head()
# Out:
#             sales_(€)
# date
# 2020-01-05   71739.29
# 2020-01-12   73268.92
# 2020-01-19   76551.39
# 2020-01-26   81131.06
# 2020-02-02   79709.22

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-12', '2020-01-19', '2020-01-26',
#                '2020-02-02', '2020-02-09', '2020-02-16', '2020-02-23',
#                '2020-03-01', '2020-03-08',
#                ...
#                '2022-02-06', '2022-02-13', '2022-02-20', '2022-02-27',
#                '2022-03-06', '2022-03-13', '2022-03-20', '2022-03-27',
#                '2022-04-03', '2022-04-10'],
#               dtype='datetime64[ns]', name='date', length=119, freq='W-SUN')

# %% [markdown]
# # Visualizing the data

# %%
import warnings
import matplotlib.pyplot as plt
y = df['sales_(€)']
fig, ax = plt.subplots(figsize=(20, 6))
ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Weekly')
ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.set_ylabel('sales_(€)')
ax.legend();

# %% [markdown]
# # Decomposing the Data

# %%
import statsmodels.api as sm

# graphs to show seasonal_decompose
def seasonal_decompose (y):
    decomposition = sm.tsa.seasonal_decompose(y, model='additive',extrapolate_trend='freq')
    fig = decomposition.plot()
    fig.set_size_inches(14,7)
    plt.show()

# %%
seasonal_decompose(y)

# %% [markdown]
# # Checking Stationary

# %% [markdown]
# ## Visualization: Graphing the rolling statistics

# %%
### plot for Rolling Statistic for testing Stationarity
def test_stationarity(timeseries, title):
    
    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=12).mean() 
    rolstd = pd.Series(timeseries).rolling(window=12).std()
    
    fig, ax = plt.subplots(figsize=(16, 4))
    ax.plot(timeseries, label= title)
    ax.plot(rolmean, label='rolling mean');
    ax.plot(rolstd, label='rolling std (x10)');
    ax.legend()

# %%
pd.options.display.float_format = '{:.8f}'.format
test_stationarity(y,'raw data')

# %% [markdown]
# ## Augmented Dickey-Fuller Test

# %%
# Augmented Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller

def ADF_test(timeseries, dataDesc):
    print(' > Is the {} stationary ?'.format(dataDesc))
    dftest = adfuller(timeseries.dropna(), autolag='AIC')
    print('Test statistic = {:.3f}'.format(dftest[0]))
    print('P-value = {:.3f}'.format(dftest[1]))
    print('Critical values :')
    for k, v in dftest[4].items():
        print('\t{}: {} - The data is {} stationary with {}% confidence'.format(k, v, 'not' if v<dftest[0] else '', 100-int(k[:-1])))

# %%
ADF_test(y,'raw data')
# Out:
#  > Is the raw data stationary ?
# Test statistic = -5.893
# P-value = 0.000
# Critical values :
# 	1%: -3.487517288664615 - The data is  stationary with 99% confidence
# 	5%: -2.8865777180380032 - The data is  stationary with 95% confidence
# 	10%: -2.5801239192052012 - The data is  stationary with 90% confidence

# %% [markdown]
# ## Detrending

# %%
# Detrending
y_detrend =  (y - y.rolling(window=12).mean())/y.rolling(window=12).std()

test_stationarity(y_detrend,'de-trended data')
ADF_test(y_detrend,'de-trended data')
# Out:
#  > Is the de-trended data stationary ?
# Test statistic = -5.264
# P-value = 0.000
# Critical values :
# 	1%: -3.492995948509562 - The data is  stationary with 99% confidence
# 	5%: -2.888954648057252 - The data is  stationary with 95% confidence
# 	10%: -2.58139291903223 - The data is  stationary with 90% confidence

# %% [markdown]
# ## Differencing

# %%
# Differencing
y_12lag =  y - y.shift(12)

test_stationarity(y_12lag,'12 lag differenced data')
ADF_test(y_12lag,'12 lag differenced data')
# Out:
#  > Is the 12 lag differenced data stationary ?
# Test statistic = -5.250
# P-value = 0.000
# Critical values :
# 	1%: -3.4942202045135513 - The data is  stationary with 99% confidence
# 	5%: -2.889485291005291 - The data is  stationary with 95% confidence
# 	10%: -2.5816762131519275 - The data is  stationary with 90% confidence

# %% [markdown]
# ## Detrending + Differencing

# %%
# Detrending + Differencing

y_12lag_detrend =  y_detrend - y_detrend.shift(12)

test_stationarity(y_12lag_detrend,'12 lag differenced de-trended data')
ADF_test(y_12lag_detrend,'12 lag differenced de-trended data')
# Out:
#  > Is the 12 lag differenced de-trended data stationary ?
# Test statistic = -3.660
# P-value = 0.005
# Critical values :
# 	1%: -3.505190196159122 - The data is  stationary with 99% confidence
# 	5%: -2.894232085048011 - The data is  stationary with 95% confidence
# 	10%: -2.5842101234567902 - The data is  stationary with 90% confidence

# %% [markdown]
# # Set the y_train, y_test, and the length of predict units

# %%
y_train = y[:'2021-12-05'] # dataset to train
y_val = y['2021-12-12':] # last X months for test  
predict_date = len(y) - len(y[:'2021-12-12']) # the number of data points for the test set

# %% [markdown]
# # Sarima

# %%
import itertools

def sarima_grid_search(y,seasonal_period):
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2],seasonal_period) for x in list(itertools.product(p, d, q))]
    
    mini = float('+inf')
    
    
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                mod = sm.tsa.statespace.SARIMAX(y,
                                                order=param,
                                                seasonal_order=param_seasonal,
                                                enforce_stationarity=False,
                                                enforce_invertibility=False)

                results = mod.fit()
                
                if results.aic < mini:
                    mini = results.aic
                    param_mini = param
                    param_seasonal_mini = param_seasonal

# print('SARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            except:
                continue
    print('The set of parameters with the minimum AIC is: SARIMA{}x{} - AIC:{}'.format(param_mini, param_seasonal_mini, mini))

# %%
sarima_grid_search(y,36)
# Out:
# The set of parameters with the minimum AIC is: SARIMA(0, 1, 1)x(1, 1, 1, 36) - AIC:958.3588906572352

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# Call this function after pick the right(p,d,q) for SARIMA based on AIC               
def sarima_eva(y,order,seasonal_order,seasonal_period,pred_date,y_test):
    # fit the model 
    mod = sm.tsa.statespace.SARIMAX(y,
                                order=order,
                                seasonal_order=seasonal_order,
                                #enforce_stationarity=False,
                                enforce_invertibility=False)

    results = mod.fit()
    print(results.summary().tables[1])
    
    results.plot_diagnostics(figsize=(16, 8))
    plt.show()
    
    # The dynamic=False argument ensures that we produce one-step ahead forecasts, 
    # meaning that forecasts at each point are generated using the full history up to that point.
    pred = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=False)
    pred_ci = pred.conf_int()
    y_forecasted = pred.predicted_mean
    mse = ((y_forecasted - y_test) ** 2).mean()
    mape = round(mean_absolute_percentage_error(y_test, y_forecasted)*100, 3)
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = False {}'.format(seasonal_period,round(np.sqrt(mse), 2)))
    print(f"MAPE = {mape}")

    ax = y.plot(label='observed')
    y_forecasted.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('date')
    ax.set_ylabel('Sessions')
    plt.legend()
    plt.show()

    # A better representation of our true predictive power can be obtained using dynamic forecasts. 
    # In this case, we only use information from the time series up to a certain point, 
    # and after that, forecasts are generated using values from previous forecasted time points.
    pred_dynamic = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=True, full_results=True)
    pred_dynamic_ci = pred_dynamic.conf_int()
    y_forecasted_dynamic = pred_dynamic.predicted_mean
    mse_dynamic = ((y_forecasted_dynamic - y_test) ** 2).mean()
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = True {}'.format(seasonal_period,round(np.sqrt(mse_dynamic), 2)))

    ax = y.plot(label='observed')
    y_forecasted_dynamic.plot(label='Dynamic Forecast', ax=ax,figsize=(14, 7))
    ax.fill_between(pred_dynamic_ci.index,
                    pred_dynamic_ci.iloc[:, 0],
                    pred_dynamic_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('date')
    ax.set_ylabel('Sessions')

    plt.legend()
    plt.show()
    
    return (results)

# %%
model = sarima_eva(y,(0, 1, 1),(1, 1, 1, 36),36,'2021-12-12',y_val)
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.0097      0.185     -0.053      0.958      -0.373       0.354
# ar.S.L36      -0.6217      0.169     -3.682      0.000      -0.953      -0.291
# ma.S.L36      -0.1627      0.357     -0.456      0.649      -0.862       0.537
# sigma2      2.491e+08   2.42e-10   1.03e+18      0.000    2.49e+08    2.49e+08
# ==============================================================================
# The Root Mean Squared Error of SARIMA with season_length=36 and dynamic = False 10299.53
# MAPE = 10.108
# The Root Mean Squared Error of SARIMA with season_length=36 and dynamic = True 28215.93

# %% [markdown]
# # Making Predictions

# %%
def forecast(model,predict_steps,y):
    
    pred_uc = model.get_forecast(steps=predict_steps)

    #SARIMAXResults.conf_int, can change alpha,the default alpha = .05 returns a 95% confidence interval.
    pred_ci = pred_uc.conf_int()

    ax = y.plot(label='observed', figsize=(14, 7))
#     print(pred_uc.predicted_mean)
    pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.25)
    ax.set_xlabel('date')
    ax.set_ylabel(y.name)

    plt.legend()
    plt.show()
    
    # Produce the forcasted tables 
    pm = pred_uc.predicted_mean.reset_index()
    pm.columns = ['date','Predicted_Mean']
    pci = pred_ci.reset_index()
    pci.columns = ['date','Lower Bound','Upper Bound']
    final_table = pm.join(pci.set_index('date'), on='date')
    
    return (final_table)

# %%
final_table = forecast(model,36,y)
final_table.head()
# Out:
#         date  Predicted_Mean    Lower Bound     Upper Bound
# 0 2022-04-17 108339.45707528 77402.72698029 139276.18717026
# 1 2022-04-24  99716.98617347 56178.33375941 143255.63858754
# 2 2022-05-01  80653.58296782 27416.87346118 133890.29247445
# 3 2022-05-08  72802.78422642 11380.63655837 134224.93189447
# 4 2022-05-15  70804.58986920  2166.31185163 139442.86788676

# %% [markdown]
# ## Graphs without the confident interval

# %%
pred_uc = model.get_forecast(steps=36)
ax = y.plot(label='observed', figsize=(14, 7))
#print(pred_uc.predicted_mean)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('date')
ax.set_ylabel(y.name)
ax.set_title("Q4-2022", fontsize = 15)

plt.legend()
plt.show()

# %% [markdown]
# ## Graphs show only the perdiected period

# %%
final_table.index = final_table.date
fig, ax = plt.subplots( figsize=(14, 7))
# ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Weekly')
ax.plot(final_table.Predicted_Mean,marker='.', linestyle='-', linewidth=0.5, label='Predicted Weekly')
# ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.plot(final_table.Predicted_Mean.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Predicted Monthly Mean Resample')
ax.set_ylabel('sales_(€)')
ax.set_xlabel("date")
ax.set_title("Q4-2022", fontsize = 15)
ax.legend();
